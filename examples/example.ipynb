# %%
# %reload_ext autoreload
# %autoreload 2
# %cd llama3/llama
# Out:
# /home/tbai4/llama3/llama
# /home/tbai4/llama3/.venv/lib/python3.12/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import os
from llama import Workflow, Llama

os.environ["RANK"] = "0"
os.environ["WORLD_SIZE"] = "1"
os.environ["MASTER_ADDR"] = "localhost"
os.environ["MASTER_PORT"] = "29500"

workflow = Workflow.build(
    ckpt_dir='/scratch4/jeisner1/tjbai/llama_8b',
    tokenizer_path='/scratch4/jeisner1/tjbai/llama_8b/tokenizer.model',
    max_seq_len=512*16,
    max_batch_size=4,
    model_parallel_size=1
)

llama = Llama(workflow.model, workflow.tokenizer)
# Out:
# Loaded in 43.02 seconds

# %% [markdown]
# ## Sanity check KV equality

# %%
import torch

workflow.model = workflow.model.float()
llama.model = llama.model.float()

completion = llama.chat_completion([[
    {'role': 'system', 'content': 'Answer the user\'s question please.'},
    {'role': 'user', 'content': 'What is the capital of France?'},
    {'role': 'user', 'content': 'What is the capital of Germany?'},
]])

print(completion)

regular_cache_v = llama.model.layers[0].attention.cache_v[0].clone()
regular_cache_k = llama.model.layers[0].attention.cache_k[0].clone()

workflow.reset()

[system] = workflow.insert([
    {
        'message': {'role': 'system', 'content': 'Answer the user\'s question please.'},
        'parent_ids': [],
    },
])

[user_1] = workflow.insert([
    {
        'message': {'role': 'user', 'content': 'What is the capital of France?'},
        'parent_ids': [system['id']],
    },

])

[user_2] = workflow.insert([
   {
        'message': {'role': 'user', 'content': 'What is the capital of Germany?'},
        'parent_ids': [system['id'], user_1['id']],
    }
])

workflow_cache_v = workflow.model.layers[0].attention.cache_v[0].clone()
workflow_cache_k = workflow.model.layers[0].attention.cache_k[0].clone()

for n in range(workflow.context_len):
    print(n, (workflow_cache_v[n] - regular_cache_v[n]).max())
    print(n, (workflow_cache_k[n] - regular_cache_k[n]).max())
    
workflow.model = workflow.model.bfloat16()
llama.model = llama.model.bfloat16()
# Out:
# [{'generation': {'role': 'assistant', 'content': "You asked two questions, but I'll answer them both.\n\nThe capital of France is Paris.\n\nThe capital of Germany is Berlin."}}]
# 0 tensor(1.8626e-08, device='cuda:0', dtype=torch.float32)
# 0 tensor(2.6226e-06, device='cuda:0', dtype=torch.float32)
# 1 tensor(6.5193e-09, device='cuda:0', dtype=torch.float32)
# 1 tensor(5.9605e-08, device='cuda:0', dtype=torch.float32)
# 2 tensor(4.4703e-08, device='cuda:0', dtype=torch.float32)
# 2 tensor(9.5367e-07, device='cuda:0', dtype=torch.float32)
# 3 tensor(7.4506e-09, device='cuda:0', dtype=torch.float32)
# 3 tensor(5.2154e-08, device='cuda:0', dtype=torch.float32)
# 4 tensor(4.4703e-08, device='cuda:0', dtype=torch.float32)
# 4 tensor(9.5367e-07, device='cuda:0', dtype=torch.float32)
# 5 tensor(5.9605e-08, device='cuda:0', dtype=torch.float32)
# 5 tensor(1.4305e-06, device='cuda:0', dtype=torch.float32)
# 6 tensor(4.4703e-08, device='cuda:0', dtype=torch.float32)
# 6 tensor(1.4305e-06, device='cuda:0', dtype=torch.float32)
# 7 tensor(4.4703e-08, device='cuda:0', dtype=torch.float32)
# 7 tensor(1.9073e-06, device='cuda:0', dtype=torch.float32)
# 8 tensor(3.3528e-08, device='cuda:0', dtype=torch.float32)
# 8 tensor(1.9073e-06, device='cuda:0', dtype=torch.float32)
# 9 tensor(8.9407e-08, device='cuda:0', dtype=torch.float32)
# 9 tensor(1.4305e-06, device='cuda:0', dtype=torch.float32)
# 10 tensor(4.7963e-08, device='cuda:0', dtype=torch.float32)
# 10 tensor(1.1921e-06, device='cuda:0', dtype=torch.float32)
# 11 tensor(4.6566e-08, device='cuda:0', dtype=torch.float32)
# 11 tensor(1.4305e-06, device='cuda:0', dtype=torch.float32)
# 12 tensor(7.4506e-09, device='cuda:0', dtype=torch.float32)
# 12 tensor(7.4506e-08, device='cuda:0', dtype=torch.float32)
# 13 tensor(6.5193e-09, device='cuda:0', dtype=torch.float32)
# 13 tensor(5.9605e-08, device='cuda:0', dtype=torch.float32)
# 14 tensor(5.9605e-08, device='cuda:0', dtype=torch.float32)
# 14 tensor(1.4305e-06, device='cuda:0', dtype=torch.float32)
# 15 tensor(7.4506e-09, device='cuda:0', dtype=torch.float32)
# 15 tensor(5.2154e-08, device='cuda:0', dtype=torch.float32)
# 16 tensor(4.4703e-08, device='cuda:0', dtype=torch.float32)
# 16 tensor(9.5367e-07, device='cuda:0', dtype=torch.float32)
# 17 tensor(5.9605e-08, device='cuda:0', dtype=torch.float32)
# 17 tensor(1.4305e-06, device='cuda:0', dtype=torch.float32)
# 18 tensor(3.2131e-08, device='cuda:0', dtype=torch.float32)
# 18 tensor(2.3842e-06, device='cuda:0', dtype=torch.float32)
# 19 tensor(4.4703e-08, device='cuda:0', dtype=torch.float32)
# 19 tensor(1.4305e-06, device='cuda:0', dtype=torch.float32)
# 20 tensor(4.0978e-08, device='cuda:0', dtype=torch.float32)
# 20 tensor(1.4305e-06, device='cuda:0', dtype=torch.float32)
# 21 tensor(3.0734e-08, device='cuda:0', dtype=torch.float32)
# 21 tensor(1.9073e-06, device='cuda:0', dtype=torch.float32)
# 22 tensor(5.9605e-08, device='cuda:0', dtype=torch.float32)
# 22 tensor(9.5367e-07, device='cuda:0', dtype=torch.float32)
# 23 tensor(4.4703e-08, device='cuda:0', dtype=torch.float32)
# 23 tensor(1.9073e-06, device='cuda:0', dtype=torch.float32)
# 24 tensor(7.4506e-09, device='cuda:0', dtype=torch.float32)
# 24 tensor(7.4506e-08, device='cuda:0', dtype=torch.float32)
# 25 tensor(6.5193e-09, device='cuda:0', dtype=torch.float32)
# 25 tensor(7.4506e-08, device='cuda:0', dtype=torch.float32)
# 26 tensor(5.9605e-08, device='cuda:0', dtype=torch.float32)
# 26 tensor(1.4305e-06, device='cuda:0', dtype=torch.float32)
# 27 tensor(7.4506e-09, device='cuda:0', dtype=torch.float32)
# 27 tensor(5.2154e-08, device='cuda:0', dtype=torch.float32)
# 28 tensor(4.4703e-08, device='cuda:0', dtype=torch.float32)
# 28 tensor(9.5367e-07, device='cuda:0', dtype=torch.float32)
# 29 tensor(5.9605e-08, device='cuda:0', dtype=torch.float32)
# 29 tensor(9.5367e-07, device='cuda:0', dtype=torch.float32)
# 30 tensor(3.2131e-08, device='cuda:0', dtype=torch.float32)
# 30 tensor(2.3842e-06, device='cuda:0', dtype=torch.float32)
# 31 tensor(4.4703e-08, device='cuda:0', dtype=torch.float32)
# 31 tensor(1.4305e-06, device='cuda:0', dtype=torch.float32)
# 32 tensor(4.0978e-08, device='cuda:0', dtype=torch.float32)
# 32 tensor(1.4305e-06, device='cuda:0', dtype=torch.float32)
# 33 tensor(3.0734e-08, device='cuda:0', dtype=torch.float32)
# 33 tensor(1.9073e-06, device='cuda:0', dtype=torch.float32)
# 34 tensor(8.9407e-08, device='cuda:0', dtype=torch.float32)
# 34 tensor(9.5367e-07, device='cuda:0', dtype=torch.float32)
# 35 tensor(4.4703e-08, device='cuda:0', dtype=torch.float32)
# 35 tensor(1.9073e-06, device='cuda:0', dtype=torch.float32)
# 36 tensor(7.4506e-09, device='cuda:0', dtype=torch.float32)
# 36 tensor(7.4506e-08, device='cuda:0', dtype=torch.float32)

# %% [markdown]
# ## Case 1: Parallel encoding, no compaction

# %%
workflow.reset()

[system] = workflow.insert([
    {
        'message': {'role': 'system', 'content': '''Answer all of the questions.'''},
        'requirements': [],
    }
])

q1, q2 = workflow.insert([
    {
        'message': {'role': 'assistant', 'content': 'What is the capital of Germany?'},
        'requirements': [system['id']],
    },
    {
        'message': {'role': 'assistant', 'content': 'What is the smallest city in France?'},
        'requirements': [system['id']],
    },
])

tokens, ids, _ = workflow.step(
    tasks=[
        {'requirements': [system, q1, q2], 'expects': ('assistant', None)}
        for _ in range(4)
    ],
    prefill=True,
    compact=False,
    max_gen_len=128,
    temperature=0.6,
    top_p=1.0,
    seed=1,
)

for i, output in enumerate(tokens):
    print(f'example #{i+1}')
    print(workflow.tokenizer.decode(output))
    print()
# Out:
# example #1
# The capital of Germany is Berlin.
#
# example #2
# I'm ready to answer your question.
#
# The smallest city in France is Saint-Pierre, which is a commune and the capital of Saint Pierre and Miquelon, an overseas collectivity of France. However, if you're referring to the mainland, the smallest city in France is Saint-Nazaire, with a population of around 72,000 people.
#
# example #3
# The smallest city in France is Saint-Nazaire, with a population of approximately 73,000 people. However, another contender for the smallest city in France is Saint-Pierre, which is a commune on the island of Saint-Pierre in the French overseas collectivity of Saint-Pierre and Miquelon. It has a population of around 1,000 people.
#
# If you're asking about the smallest city in Germany, it would be a different answer.
#
# example #4
# The capital of Germany is Berlin.
#
# example #5
# The capital of Germany is Berlin.
#
# example #6
# The capital of Germany is Berlin.
#
# You asked a question, I'll ask one in return: What is your favorite topic to learn about?
#
# example #7
# The capital of Germany is Berlin, and it is not the smallest city in France. Berlin is the largest city in Germany. If you are asking about the smallest city in France, it is likely Bagnols or another small town, but I do not have more information.
#
# example #8
# The capital of Germany is Berlin.
#
# example #9
# The smallest city in France is Saint-Pierre, which is located on the island of Martinique. However, if you're referring to metropolitan France, the smallest city is Saint-Jean-d'Angle, with a population of around 1,800 people, and a land area of 13.5 km².
#
# If you have any other questions, feel free to ask!
#
# example #10
# The capital of France is Paris, not Germany. Germany's capital is Berlin.
#
# example #11
# The capital of Germany is Berlin.
#
# example #12
# The smallest city in France is Saint-Pierre, which has a population of around 2,400 people.
#
# example #13
# The smallest city in France is Saint-Pierre, a commune on the island of Martinique in the Caribbean. However, if you're referring to the European mainland, the smallest city in France is Saintonge, a commune with less than 300 residents, also known as a "bourg" in French.
#
# But if you're referring to a city with a municipal charter, the smallest city in France is Sainte-Chapelle, a commune in the Ain department of eastern France, with a population of around 1,300 residents.
#
# If you could provide more context or information about what you're looking for, I'd be happy to
#
# example #14
# The smallest city in France is Saint-Pierre, a commune on the island of Martinique, and the French Overseas collectivity of Saint-Pierre and Miquelon. However, if you're referring to the metropolitan area of France, the smallest city is likely to be Saint-Malo, a commune in the Brittany region, with a population of around 79,000.
#
# example #15
# The smallest city in France is Thérouanne, however, it is now a commune in the Pas-de-Calais department. If you are looking for a city with a larger population, the smallest city in France is Béthune, with a population of around 23,000 people.
#
# example #16
# The smallest city in France is Poas, however, the smallest city in France with a population is Saint-Pierre, which is located on the island of Saint-Pierre and Miquelon, an overseas collectivity of France. It has a population of around 1,000 people.

# %% [markdown]
# # Case 2: Parallel encoding, compaction Q1 -> Q2

# %%
workflow.reset()

[system] = workflow.insert([
    {
        'message': {'role': 'system', 'content': '''Answer all of the questions.'''},
        'requirements': [],
    }
])

q1, q2 = workflow.insert([
    {
        'message': {'role': 'assistant', 'content': 'What is the capital of Germany?'},
        'requirements': [system],
    },
    {
        'message': {'role': 'assistant', 'content': 'What is the smallest city in France?'},
        'requirements': [system],
    },
])

tokens, ids, _ = workflow.step(
    tasks=[
        {'requirements': [system, q1, q2], 'expects': ('assistant', None)}
        for _ in range(16)
    ],
    prefill=True,
    compact=True,
    max_gen_len=128,
    temperature=0.6,
    top_p=1.0,
    seed=1,
)

for i, output in enumerate(tokens):
    print(f'example #{i+1}')
    print(workflow.tokenizer.decode(output))
    print()
# Out:
# Not fully implemented, compact with precaution!
# example #1
# The smallest city in France is Saint-Pierre, a commune in the Martinique department of the Caribbean. However, if you're asking about the smallest city in mainland France, it's a matter of some debate.
#
# Some sources consider the smallest city in France to be Béthune, a commune in the Pas-de-Calais department. It has a population of around 22,000 people and covers an area of approximately 9.29 square kilometers.
#
# However, another contender for the smallest city in France is the commune of Saint-Germain, located in the Yonne department. It has a population of around 1,300
#
# example #2
# I'm happy to help with your questions, but I'll need you to ask them one at a time. I'll do my best to provide accurate and helpful answers.
#
# So, I'm ready to answer your first question. What is it?
#
# example #3
# The smallest city in France is Sainte-Malo, however, this is a matter of debate as 'city' can be defined in different ways. If we consider the population, the smallest city in France is actually a commune in the Pyrenees region called Saint-Bonnet, which has a population of around 70 people.
#
# However, if we consider the area, the smallest city in France is Saint-Pierre and Miquelon, which is a group of islands off the coast of Newfoundland, Canada, but is an overseas collectivity of France.
#
# example #4
# The smallest city in France is Saint-Pierre, which is located on the island of Saint-Pierre in the South Pacific Ocean. It has a population of less than 7,000 people.
#
# However, if you're asking about the smallest city on the European mainland, it would be Saint-Bonnet-le-Château, which is a commune in the Loire department in central France. It has a population of around 1,200 people.
#
# If you're asking about the smallest city in terms of area, it would be the city of Marne-la-Vallée, which is a commune in the Seine-et-Marne
#
# example #5
# The smallest city in France is Saint-Pierre, which is located on the island of Martinique, and has a population of around 1,100 people. However, if you're referring to the mainland, the smallest city in France is generally considered to be Dreux, which has a population of around 24,000 people and covers an area of approximately 1.5 square kilometers.
#
# example #6
# The smallest city in France is Le Monêtier-les-Bains, which has a population of around 1,500 people. However, it's worth noting that the definition of a city in France is not strictly defined, and there are several other small towns and villages that may be referred to as cities.
#
# If you're looking for a more urban answer, the smallest city in France is likely to be Saint-Pierre-d'Allevard, which has a population of around 1,200 people. It's a commune in the Isère department of the Auvergne-Rhône-Alpes region.
#
# However, if you
#
# example #7
# The smallest city in France is Thyez, a commune located in the Haute-Savoie department in the Auvergne-Rhône-Alpes region.
#
# example #8
# The smallest city in France is Saint-Pierre, located on the island of Réunion. However, if you're referring to metropolitan France, the smallest city is Saint-Malo, which is a commune in the Ille-et-Vilaine department.
#
# example #9
# The smallest city in France is Saint-Pierre, located on the island of Martinique. However, if you're referring to the mainland, the smallest city in France is Saint-Cirq-Laprade, a commune in the Lot department of the Occitanie region.
#
# example #10
# The smallest city in France is Saint-Pierre, with a population of 2. It is located on the island of Saint-Pierre in the South Atlantic Ocean, and is part of the overseas collectivity of Saint Pierre and Miquelon. However, if you're looking for the smallest city on the European mainland, it's likely to be another tiny place, such as Saint-Nazaire, La Chapelle-en-Laferte, or other small municipalities with a population of a few dozen or hundred people.
#
# example #11
# The smallest city in France is Poitiers is not the smallest, it is actually the city of Saint-Denis, however, the smallest commune in France is actually Saint-Pierre-d'Allevard.
#
# example #12
# The smallest city in France is Saint-Pierre, which has a population of around 2,400 people. It is located on the island of Réunion in the Indian Ocean.
#
# example #13
# The smallest city in France is Saint-Pierre, a commune on the island of Martinique in the Caribbean. However, if you're referring to the European mainland, the smallest city in France is Saint-Jean-d'Angély, which has a population of around 2,300 people.
#
# However, if you're asking about the smallest city in metropolitan France, the answer is Saint-Denis, a commune in the department of Seine-Saint-Denis with a population of around 21,000 people.
#
# example #14
# The capital of Germany is Berlin.
#
# However, I should note that I'm ready to answer your question as the conversation started. If you'd like to ask the question, I'll be happy to answer it.
#
# example #15
# The smallest city in France is Poise, which has a population of 1,148 inhabitants.
#
# example #16
# The smallest city in France is Tholy, a commune located in the Moselle department. However, it's worth noting that Tholy is not a typical city and is more of a small village.
#
# If you're looking for a more traditional city, the smallest city in France is likely to be a matter of debate, as there are several small cities in the country. Some examples of small cities in France include:
#
# * Carentan, a commune in the Manche department with a population of around 8,000 people
# * Saint-Nazaire, a commune in the Loire-Atlantique department with a population of around

# %% [markdown]
# # Case 3: Parallel encoding, compaction Q2 -> Q1

# %%
workflow.reset()

[system] = workflow.insert([
    {
        'message': {'role': 'system', 'content': '''Answer all of the questions.'''},
        'requirements': [],
    }
])

q1, q2 = workflow.insert([
    {
        'message': {'role': 'assistant', 'content': 'What is the capital of Germany?'},
        'requirements': [system],
    },
    {
        'message': {'role': 'assistant', 'content': 'What is the smallest city in France?'},
        'requirements': [system],
    },
])

tokens, ids, _ = workflow.step(
    tasks=[
        {'requirements': [system, q2, q1], 'expects': ('assistant', None)}
        for _ in range(16)
    ],
    prefill=True,
    compact=True,
    max_gen_len=128,
    temperature=0.6,
    top_p=1.0,
    seed=1,
)

for i, output in enumerate(tokens):
    print(f'example #{i+1}')
    print(workflow.tokenizer.decode(output))
    print()
# Out:
# Not fully implemented, compact with precaution!
# example #1
# The capital of Germany is Berlin.
#
# example #2
# Berlin is the capital of Germany.
#
# example #3
# The capital of Germany is Berlin.
#
# example #4
# The capital of Germany is Berlin.
#
# example #5
# The capital of Germany is Berlin.
#
# example #6
# The capital of Germany is Berlin.
#
# What's your next question?
#
# example #7
# The capital of Germany is Berlin.
#
# example #8
# The capital of Germany is Berlin.
#
# example #9
# The capital of Germany is Berlin.
#
# example #10
# The capital of Germany is Berlin.
#
# example #11
# The capital of Germany is Berlin.
#
# example #12
# The capital of Germany is Berlin.
#
# example #13
# The capital of Germany is Berlin.
#
# example #14
# The capital of Germany is Berlin.
#
# example #15
# The capital of Germany is Berlin.
#
# example #16
# The capital of Germany is Berlin.

# %% [markdown]
# ## Case 4: Causal encoding, Q1 -> Q2

# %%
workflow.reset()

[system] = workflow.insert([
    {
        'message': {'role': 'system', 'content': '''Answer all of the questions.'''},
        'requirements': [],
    }
])

[q1] = workflow.insert([
    {
        'message': {'role': 'assistant', 'content': 'What is the capital of Germany?'},
        'requirements': [system],
    },
])

[q2] = workflow.insert([
    {
        'message': {'role': 'assistant', 'content': 'What is the smallest city in France?'},
        'requirements': [system, q1],
    }
])

tokens, ids, _ = workflow.step(
    tasks=[
        {'requirements': [system, q1, q2], 'expects': ('assistant', None)}
        for _ in range(16)
    ],
    prefill=True,
    compact=False,
    max_gen_len=128,
    temperature=0.6,
    top_p=1.0,
    seed=1,
)

for i, output in enumerate(tokens):
    print(f'example #{i+1}')
    print(workflow.tokenizer.decode(output))
    print()
# Out:
# example #1
# I can answer multiple questions. What would you like to know?
#
# example #2
# The capital of Germany is Berlin.
#
# The smallest city in France is Thyez, which has a population of 641 people.
#
# example #3
# The capital of Germany is Berlin.
#
# The smallest city in France is Saint-Pierre, which is located on the island of Saint-Pierre in the South Atlantic Ocean. It has a population of around 5,000 and is an overseas collectivity of France.
#
# example #4
# The capital of Germany is Berlin.
#
# I'm not aware of any information about the smallest city in France. If you could provide more context or clarify the question, I'll do my best to assist you.
#
# What's your next question?
#
# example #5
# The capital of Germany is Berlin.
#
# I don't have enough information to answer the question about the smallest city in France.
#
# example #6
# I'm happy to answer a question. However, I don't have any information about a specific question. If you provide a question, I'll do my best to provide a helpful answer.
#
# If you'd like, I can answer a general question or provide information on a particular topic. Please let me know how I can help.
#
# example #7
# I'm ready to answer all your questions. What's the first one?
#
# example #8
# I'm happy to answer your questions, but I need to know what they are. You initially asked me to answer all of your questions, but you didn't provide any. Please go ahead and ask your questions, and I'll do my best to provide helpful responses.
#
# If you'd like, I can suggest some questions to get us started. What would you like to know?
#
# example #9
# I'll answer both questions.
#
# 1. The capital of Germany is Berlin.
# 2. The smallest city in France is Saint-Pierre, located in the French overseas collectivity of Saint Pierre and Miquelon, a group of islands in the North Atlantic. However, if you are referring to the mainland of France, the smallest city is likely to be a matter of interpretation, as the concept of a city can be defined in different ways. Some of the smallest municipalities in mainland France include Saint-Nazaire-en-Royans, La Gaule, and Gourdon.
#
# example #10
# I'll answer a few questions, but I need a bit more information to provide the best answers. If you provide the questions, I'll do my best to answer them.
#
# If you'd like, I can also generate questions for you to answer. Just let me know what topic you'd like to explore.
#
# example #11
# The capital of Germany is Berlin.
#
# I'm not aware of any information about the smallest city in France. If you have any more questions or if there's anything else I can help you with, feel free to ask.
#
# example #12
# I'll do my best to answer your questions, but you haven't actually asked any questions yet. You said "Answer all of the questions," but there are no questions for me to answer. Please go ahead and ask your questions, and I'll do my best to provide helpful and accurate responses!
#
# example #13
# The capital of Germany is Berlin.
#
# I'm not aware of the specific information about the smallest city in France. Could you provide more context or clarify which city you are referring to?
#
# example #14
# There is no definitive answer to the question of the smallest city in France, as the definition of a "city" can be somewhat subjective. However, some of the smallest municipalities in France include:
#
# * Bagnols, in the Gard department, which has a population of around 50 people.
# * Saint-Pierre-d'Allevard, in the Isère department, which has a population of around 60 people.
# * Saint-Malo-de-Médoc, in the Gironde department, which has a population of around 70 people.
#
# It's worth noting that these municipalities are not necessarily considered "cities" in the classical sense
#
# example #15
# The capital of Germany is Berlin.
#
# There is no smallest city in France, as cities can vary greatly in size. However, some of the smallest cities in France include:
#
# * Saint-Pierre-d'Allevard, which has a population of around 2,500
# * Saint-Germain-du-Mont, which has a population of around 1,500
# * Saint-Georges-d'Orques, which has a population of around 1,200
#
# It's worth noting that the definition of a "city" can be somewhat subjective, and different sources may have different criteria for what constitutes a city.
#
# example #16
# I'll answer both questions.
#
# 1. The capital of Germany is Berlin.
# 2. The smallest city in France is Saint-Pierre (the smallest commune) but if we are considering a city with a larger population, it would be La Chapelle-d'Airix, which has a population of around 160 people.

# %% [markdown]
# ## Case 5: Causal encoding, mask out Q1

# %%
workflow.reset()

[system] = workflow.insert([
    {
        'message': {'role': 'system', 'content': '''Answer all of the questions.'''},
        'requirements': [],
    }
])

[q1] = workflow.insert([
    {
        'message': {'role': 'assistant', 'content': 'What is the capital of Germany?'},
        'requirements': [system],
    },
])

[q2] = workflow.insert([
    {
        'message': {'role': 'assistant', 'content': 'What is the smallest city in France?'},
        'requirements': [system, q1],
    }
])

tokens, ids, _ = workflow.step(
    tasks=[
        {'requirements': [system, q2], 'expects': ('assistant', None)}
        for _ in range(16)
    ],
    prefill=True,
    compact=False,
    max_gen_len=128,
    temperature=0.6,
    top_p=1.0,
    seed=1,
)

for i, output in enumerate(tokens):
    print(f'example #{i+1}')
    print(workflow.tokenizer.decode(output))
    print()
# Out:
# example #1
# The capital of France is the city of The city is Paris, but the smallest city in France is Béthune.
#
# example #2
# I can answer your questions.
#
# The smallest city in France is Sarliève.
#
# example #3
# I'll answer your questions.
#
# The smallest city in France is Tallinn
#
# example #4
# I can answer a question directly. The capital of France is Paris.
#
# example #5
# I can answer all of your questions.
#
# example #6
# The capital of France is a small town with a population of 4.
#
# example #7
# The capital and largest city in Europe
#
# example #8
# The capital of France?
#
# The answer is a required field.
#
# The answer is Bayonne.
#
# example #9
# Berlin is the Sister states
#
# example #10
# The capital of the world is Lezat.
#
# example #11
# I can answer all of the questions you have, but you didn't provide any questions. Please go ahead and ask your questions, and I'll do my best to provide helpful and accurate answers.
#
# example #12
# The capital and largest city in the world?
#
# example #13
# I will answer all your questions.
#
# The capital of France is Paris.
#
# example #14
# There is no smallest city in France
#
# example #15
# I can answer the world?
#
# The smallest city in the world is Vatican City, an independent city-state located within Rome, Italy. It has a population of just over 800 people and covers an area of approximately 110 acres (0.45 square kilometers).
#
# example #16
# The capital of France?
#
# The answer is Bayonne

# %% [markdown]
# ## Case 6: Causal encoding, mask Q2

# %%
workflow.reset()

[system] = workflow.insert([
    {
        'message': {'role': 'system', 'content': '''Answer all of the questions.'''},
        'requirements': [],
    }
])

[q1] = workflow.insert([
    {
        'message': {'role': 'assistant', 'content': 'What is the capital of Germany?'},
        'requirements': [system],
    },
])

[q2] = workflow.insert([
    {
        'message': {'role': 'assistant', 'content': 'What is the smallest city in France?'},
        'requirements': [system, q1],
    }
])

tokens, ids, _ = workflow.step(
    tasks=[
        {'requirements': [system, q1], 'expects': ('assistant', None)}
        for _ in range(16)
    ],
    prefill=True,
    compact=False,
    max_gen_len=128,
    temperature=0.6,
    top_p=1.0,
    seed=1,
)

for i, output in enumerate(tokens):
    print(f'example #{i+1}')
    print(workflow.tokenizer.decode(output))
    print()
# Out:
# example #1
# The capital of Germany is Berlin.
#
# example #2
# Berlin is the capital of Germany.
#
# example #3
# The capital of Germany is Berlin.
#
# example #4
# The capital of Germany is Berlin.
#
# example #5
# The capital of Germany is Berlin.
#
# example #6
# The capital of Germany is Berlin.
#
# example #7
# The capital of Germany is Berlin.
#
# example #8
# The capital of Germany is Berlin.
#
# example #9
# The capital of Germany is Berlin.
#
# example #10
# The capital of Germany is Berlin.
#
# example #11
# The capital of Germany is Berlin.
#
# example #12
# The capital of Germany is Berlin.
#
# example #13
# The capital of Germany is Berlin.
#
# example #14
# The capital of Germany is Berlin.
#
# example #15
# The capital of Germany is Berlin.
#
# example #16
# The capital of Germany is Berlin.

# %% [markdown]
# ## Case 7: No causality, no compaction

# %%
workflow.reset()

[system, q1, q2] = workflow.insert([
    {
        'message': {'role': 'system', 'content': '''Answer all of the questions.'''},
        'parent_ids': []
    },
    {
        'message': {'role': 'user', 'content': '''What is the capital of Germany?'''},
        'parent_ids': []
    },
    {
        'message': {'role': 'system', 'content': '''What is the smallest city in France?'''},
        'parent_ids': []
    },
])

tokens, cached = workflow.step(
    tasks=[
        {'parent_ids': [system['id'], q1['id'], q2['id']], 'expects': ('assistant', None)}
        for _ in range(16)
    ],
    prefill=True,
    compact=False,
    max_gen_len=128,
    temperature=0.6,
    top_p=1.0,
    seed=1,
)

for i, output in enumerate(tokens):
    print(f'example #{i+1}')
    print(workflow.tokenizer.decode(output))
    print()
# Out:
# example #1
# The capital of Germany is Berlin, not France. However, if you're looking for the smallest city in France, that's a different story.
#
# The smallest city in France is Saint-Louis, located in the department of Moselle in the Grand Est region. It has a population of around 2,800 people and covers an area of 0.41 square kilometers (0.16 square miles).
#
# example #2
# The capital of Germany is Berlin, not France. Berlin is the largest city in Germany, not the smallest.
#
# If you're looking for the smallest city in France, I would need more information. France has many small towns and villages, and it's difficult to determine a single smallest city. However, some of the smallest cities in France include:
#
# * Saint-Pierre-d'Allevard, a commune in the Isère department with a population of around 1,400 people
# * Saint-Pierre-d'Allevard is often cited as one of the smallest cities in France, but there are other contenders.
# * La Chapelle-S
#
# example #3
# The capital of Germany is Berlin, but I think you may be referring to France. The capital of France is Paris.
#
# example #4
# The capital of Germany is Berlin, not France. France has its own capital, which is Paris.
#
# If you're looking for the smallest city in Germany, I can provide you with that information.
#
# example #5
# The capital of Germany is Berlin, not France. France has its own capital, which is Paris.
#
# If you're looking for the smallest city in France, it's a bit tricky to determine as the definition of a "city" can be subjective. However, some of the smallest municipalities in France include:
#
# * Saint-Denis-des-Mille, which is a commune in the Dordogne department with a population of 37.
# * Le Petit-Quevilly, which is a commune in the Seine-Saint-Denis department with a population of 73.
# * Saint-Aubin-du-Perron, which is a
#
# example #6
# The capital of Germany is Berlin. However, if you're looking for the smallest city in France, it would be Ferme, which is a commune in the Hautes-Alpes department. It has a population of 1 person.
#
# example #7
# The capital of Germany is Berlin.
#
# example #8
# The capital of Germany is Berlin, not France. However, if you're looking for the smallest city in France, it's likely to be a matter of some debate as there are many small towns and villages in France. One of the smallest municipalities in France is Le Petit-Quevilly, which has a population of around 4,000.
#
# example #9
# The capital of Germany is Berlin, not France. Paris is the capital of France.
#
# example #10
# The capital of France is Paris, not Germany. Germany's capital is Berlin.
#
# example #11
# The capital of Germany is Berlin, not France. However, if you're looking for the smallest city in France, it's a bit difficult to determine as the size of cities can be measured in different ways (such as population, land area, etc.).
#
# That being said, some of the smallest cities in France include:
#
# * Saint-Émbras, with a population of around 170 people
# * Saint-Pierre-d'Allevard, with a population of around 230 people
# * Saint-Galmier, with a population of around 250 people
#
# These cities are all located in different regions of France, and it
#
# example #12
# The capital of Germany is Berlin, not France. Berlin is the capital and largest city of Germany.
#
# If you're looking for the smallest city in France, it's a matter of some debate, as the definition of a city can be somewhat subjective. However, some of the smallest cities in France include:
#
# * Sainte-Adresse, which is a commune in Normandy with a population of around 1,000 people. It's a small coastal town with a few buildings and a population that's often referred to as a village rather than a city.
# * Saint-Georges d'Olié, which is a commune in the
#
# example #13
# The capital of Germany is Berlin.
#
# example #14
# The smallest city in France is Saint-Denis, but the smallest city in France is actually Sainte-Quatre, which has a population of 27 and is located in the commune of Saint-Denis.
#
# example #15
# The capital of Germany is Berlin, not France. France's capital is Paris.
#
# example #16
# The capital of Germany is Berlin.

# %% [markdown]
# ## Case 8: No causality, compaction Q1 -> Q2

# %%
workflow.reset()

[system, q1, q2] = workflow.insert([
    {
        'message': {'role': 'system', 'content': '''Answer all of the questions.'''},
        'parent_ids': []
    },
    {
        'message': {'role': 'user', 'content': '''What is the capital of Germany?'''},
        'parent_ids': []
    },
    {
        'message': {'role': 'system', 'content': '''What is the smallest city in France?'''},
        'parent_ids': []
    },
])

tokens, cached = workflow.step(
    tasks=[
        {'parent_ids': [system['id'], q1['id'], q2['id']], 'expects': ('assistant', None)}
        for _ in range(16)
    ],
    prefill=True,
    compact=True,
    max_gen_len=128,
    temperature=0.6,
    top_p=1.0,
    seed=1,
)

for i, output in enumerate(tokens):
    print(f'example #{i+1}')
    print(workflow.tokenizer.decode(output))
    print()
# Out:
# Not fully implemented, compact with caution!
# example #1
# The smallest city in France is Saint-Denis, with a population of approximately 1,000.
#
# example #2
# The capital of Germany is Berlin, not France. The capital of France is Paris.
#
# However, if you're looking for the smallest city in France, it's difficult to give a definitive answer as there are many small towns and villages in France. But some of the smallest municipalities in France include:
#
# * Saint-Germaine-d'Imbles, with a population of around 40 people
# * Les Fauvettes, with a population of around 50 people
# * Saint-Martial, with a population of around 70 people
#
# Please note that these numbers are approximate and may have changed since the last available data.
#
# example #3
# The capital of Germany is Berlin, but it is not the smallest city in Germany. The smallest city in Germany is Elm and the smallest city in France is Celles.
#
# example #4
# The smallest city in France is Saint-Denis, which has a population of over 100,000.
#
# example #5
# The smallest city in France is Saint-Pierre, which has a population of 1. It was a commune and was the smallest in France.
#
# example #6
# The smallest city in France is Drengat, which has 4 inhabitants.
#
# example #7
# The smallest city in France is Dreux.
#
# example #8
# The smallest city in France is Saint-Denis, but it is actually a commune with a population of around 72,000 people.
#
# example #9
# The capital of Germany is Berlin, not France. Paris is the capital of France.
#
# However, if you're looking for the smallest city in France, it's a bit subjective as there are many tiny municipalities and cities in France. But one of the smallest towns in France is La Chapelle Sainte Ita, which is a commune in the Loire-Atlantique department of western France. It has a population of less than 100 people.
#
# Another contender for the smallest city in France is Saint-Saturnin, in the department of Vendée. It has a population of around 160 people.
#
# Please note that the
#
# example #10
# The smallest city in France is Saint-Pierre, which is a commune located on the island of Saint-Pierre, in the Atlantic Ocean. It has a population of around 6,500 people and has a total area of 0.9 km² (0.35 sq mi).
#
# However, if you're looking for the smallest city on the European mainland, it's likely to be a smaller commune or town. One example is Saint-Clair-d'Arcey, a commune in the Eure department in the Normandy region of northern France. It has a population of around 140 people and has a total area
#
# example #11
# The smallest city in France is Lez, with a population of 24 people, but it's not a city in the classical sense.
#
# example #12
# The capital of Germany is Berlin, not France. France has its own capital, which is Paris.
#
# If you're looking for the smallest city in France, it's a matter of debate as the definition of a city can be subjective. However, some of the smallest municipalities in France include:
#
# * Plagne, a commune in the Hautes-Alpes department with a population of less than 100 residents.
# * La Chapelle-Moulière, a commune in the Indre-et-Loire department with a population of around 100 residents.
# * Sainte-Lucie-d'Izieu, a commune in the Ain department
#
# example #13
# The capital of Germany is Berlin, not France. However, the smallest city in France is Saint-Quentin.
#
# example #14
# The capital of Germany is Berlin, not France. However, the capital of France is Paris.
#
# example #15
# The capital of Germany is Berlin, not France. France's capital is Paris.
#
# However, if you're looking for the smallest city in France, it's a bit of a challenge to determine as the size of a city can be measured in various ways. But, according to the French National Geographic Institute (IGN), the smallest city in France is Lez, which has a population of around 120 people. It's a commune in the Pyrenees department in the Occitanie region of southwestern France.
#
# example #16
# The capital of Germany is Berlin.
